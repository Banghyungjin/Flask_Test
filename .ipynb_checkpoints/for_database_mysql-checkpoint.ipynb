# %%
import pymysql
# Connect to the database
con = pymysql.connect(host='localhost',
                         user='root',
                         password='1234',
                         db='busan')
cursor=con.cursor()
# Create a new record
sql = "INSERT INTO `submission` (`ids`, `target`) VALUES (%s, %s)"
cursor.execute(sql, (100000,'0'))
# connection is not autocommit by default. So we must commit to save our changes.
con.commit()
# Execute query
sql = "SELECT * FROM `submission`"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 100000, '0', datetime.datetime(2021, 4, 23, 16, 34, 49))

# %%
from sqlalchemy import create_engine
import pandas as pd
# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="1234",
                               db="busan"))
data = pd.read_csv('./data/sample_submission.csv')
data.to_sql('submission', con= engine, if_exists = 'append', chunksize=1000)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1685                 if not evt_handled:
# -> 1686                     self.dialect.do_executemany(
#    1687                         cursor, statement, parameters, context
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ...

# %%
# Create dataframe
data=pd.DataFrame({
    'book_id':[12345,12346,12347],
    'title':['Python Programming','Learn MySQL','Data Science Cookbook'],
    'price':[29,23,27]
})

# %%
data
# Out:
#    book_id                  title  price
# 0    12345     Python Programming     29
# 1    12346            Learn MySQL     23
# 2    12347  Data Science Cookbook     27

# %%
from sqlalchemy import create_engine
import pandas as pd
# create sqlalchemy engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}")
data.to_sql('books', con=engine, if_exists='append',chunksize= 1000)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-d160a4c58ae8> in <module>
#       3 # create sqlalchemy engine
#       4 engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}")
# ----> 5 data.to_sql('books', con=engine, if_exists='append',chunksize= 1000)
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
# ...
